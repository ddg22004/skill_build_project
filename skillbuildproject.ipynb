# %% [markdown]
# <a href="https://colab.research.google.com/github/ddg22004/skill_build_project/blob/main/skillbuildproject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import statistics as s

# %% [markdown]
# Reading the CSV File and creating a Dataframe.

# %%
x=pd.read_csv("Iris.csv")
z=pd.DataFrame(x)

# %%
z
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# Printing the last 5 values in the dataframe.

# %%
z.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
z.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
z.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
dup=z.duplicated()

# %%
dup.sum()
# Out:
# 0

# %%
z["Species"].unique()
z["Species"].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
x=z["Species"]
y=z["SepalLengthCm"]
val=z["SepalWidthCm"]
spe1=z[z["Species"]=='Iris-setosa']
spe2=z[z["Species"]=='Iris-virginica']
spe3=z[z["Species"]=='Iris-versicolor']
z.plot(x='Species', y='SepalLengthCm',kind='scatter',color='b',marker="|")
#Displaying The Plot
plt.title("Species vs the Sepal Length")
plt.show()
z.plot(x='Species', y='SepalWidthCm',kind='scatter',marker="_")
#Displaying The Plot
plt.title("Sepal Width vs Species")
plt.show()

# %%
print("Mean of Iris setosa sepal length ",sum(spe1['SepalLengthCm'])/len(spe1),"cm") #Mean value of Sepal length of Iris Sentosa
print("Mean of Iris virginica sepal length",sum(spe2['SepalLengthCm'])/len(spe2),"cm") #Mean value of Sepal length of Iris Virginica
print("Mean of Iris versicolor sepal length",sum(spe3['SepalLengthCm'])/len(spe3),"cm") #Mean value of Sepal length of Iris Versicolor
# Out:
# Mean of Iris setosa sepal length  5.005999999999999 cm
# Mean of Iris virginica sepal length 6.587999999999998 cm
# Mean of Iris versicolor sepal length 5.936 cm

# %%
z.isnull()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %%
z.dropna()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# In the following data set there are no null values or duplicate values.

# %%
plt.figure()


plt.scatter(spe1['PetalWidthCm'],spe1['PetalLengthCm'],s=25,c='cyan',label='sentosa')
plt.scatter(spe2['PetalWidthCm'],spe2['PetalLengthCm'],s=25,c='r',label='virginca')
plt.scatter(spe3['PetalWidthCm'],spe3['PetalLengthCm'],s=25,c='b',label='vesricolor')
plt.title("Petal width and Petal length")
plt.xlabel("Petal Width")
plt.ylabel("Petal Length")
plt.legend(['setosa','virginica','versicolor'])

# %%
print("Mean value of petal length of Iris Sentosa",sum(spe1['PetalLengthCm'])/len(spe1),"cm") #Mean value of petal length of Iris Sentosa
print("Mean value of petal length of Iris Virginica",sum(spe2['PetalLengthCm'])/len(spe2),"cm") #Mean value of petal length of Iris Virginica
print("Mean value of petal length of Iris Vericolor",sum(spe3['PetalLengthCm'])/len(spe3),"cm") #Mean value of petal length of Iris Versicolor
# Out:
# Mean value of petal length of Iris Sentosa 1.464 cm
# Mean value of petal length of Iris Virginica 5.552 cm
# Mean value of petal length of Iris Vericolor 4.26 cm

# %%
print("Mean value of petal width of Iris Sentosa",sum(spe1['PetalWidthCm'])/len(spe1),"cm")
print("Mean value of petal width of Iris Virginica",sum(spe2['PetalWidthCm'])/len(spe2),"cm")
print("Mean value of petal width of Iris Vericolor",sum(spe3['PetalWidthCm'])/len(spe3),"cm")
# Out:
# Mean value of petal width of Iris Sentosa 0.2439999999999999 cm
# Mean value of petal width of Iris Virginica 2.026 cm
# Mean value of petal width of Iris Vericolor 1.3259999999999998 cm

# %%
print("Mean value of sepal width of Iris Sentosa",sum(spe1['SepalWidthCm'])/len(spe1),"cm")
print("Mean value of sepal width of Iris Virginica",sum(spe2['SepalWidthCm'])/len(spe2),"cm")
print("Mean value of sepal width of Iris Vericolor",sum(spe3['SepalWidthCm'])/len(spe3),"cm")
# Out:
# Mean value of sepal width of Iris Sentosa 3.4180000000000006 cm
# Mean value of sepal width of Iris Virginica 2.9739999999999998 cm
# Mean value of sepal width of Iris Vericolor 2.7700000000000005 cm
